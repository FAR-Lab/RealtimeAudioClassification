# %% [markdown]
# # Load library

# %%
from importlib import reload
import RealtimeAudio as RTA
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Run Program

# %% [markdown]
# This involves creating an audio buffer that we continually update with information from the microphone, then creating an image and running it through the neural net. This happens as fast as possible over and over again.

# %%
array = RTA.RunProgram(targetLength=30,AmmountOfClassesToDisplay=2,ModelPath="../models/CatDogResNet.pth")
array=np.array(array)
outputarray1=[0]
outputarray2=[0]
for samp in array:
    last = outputarray[-1]
    outputarra1.append(last*0.9+samp*0.1)
    outputarra2.append(last*0.8+samp*0.2)
plt.plot(array)
plt.plot(outputarray)
# Out:
# ---
# Predicted:	Cats 	| Probablilty: 	0.14
# Predicted:	Dogs 	| Probablilty: 	-0.15
# Stopping!
# Stopped and Done!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-b08b8a5b4b39> in <module>
#       3 outputarray1=[0]
#       4 outputarray2=[0]
# ----> 5 for samp in array:
#       6     last = outputarray[-1]
#       7     outputarra1.append(last*0.9+samp*0.1)
#
# TypeError: iteration over a 0-d array

# %%
reload(RTA)
# Out:
# <module 'RealtimeAudio' from '/Users/dg/GitRepos/RealtimeAudioClassification/03_Running/RealtimeAudio.py'>

# %%
outputarray1=[0]
outputarray2=[0]
for samp in array:
    last = outputarray[-1]
    outputarray1.append(last*0.9+samp*0.1)
    outputarray2.append(last*0.8+samp*0.2)
plt.plot(array,c='b')
plt.plot(outputarray1,c='r')
plt.plot(outputarray2,c='g')

# %%
over = np.array(outputarray1)-np.array(outputarray2)

# %%
plt.plot(over>0,c='g')
